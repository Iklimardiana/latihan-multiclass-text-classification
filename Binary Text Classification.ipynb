# %%
import pandas as pd
df = pd.read_csv('yelp_labelled.txt', names=['sentence', 'label'], sep='\t')

# %%
df.tail()
# Out:
#                                               sentence  label
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0

# %%
# bagi dataset menjadi train dan test set

from sklearn.model_selection import train_test_split
kalimat = df['sentence'].values
y = df['label'].values
kalimat_latih, kalimat_test, y_latih, y_test = train_test_split(kalimat, y, test_size=0.2)

# %%
# melakukan tokenisasi

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words=250, oov_token='x')
tokenizer.fit_on_texts(kalimat_latih)
tokenizer.fit_on_texts(kalimat_test)

sekuens_latih = tokenizer.texts_to_sequences(kalimat_latih)
sekuens_test = tokenizer.texts_to_sequences(kalimat_test)

padded_latih = pad_sequences(sekuens_latih, maxlen=20)
padded_test = pad_sequences(sekuens_test, maxlen=20)

# %%
# membuat arsitektur dengan layer embedding

import tensorflow as tf
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(250, 16, input_length=20),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
# memulai pelatihan model

num_epochs = 30
history = model.fit(padded_latih, y_latih, epochs=num_epochs,
                    validation_data=(padded_test, y_test), verbose=2)
# Out:
# Epoch 1/30
# 25/25 - 2s - loss: 0.6927 - accuracy: 0.5125 - val_loss: 0.6899 - val_accuracy: 0.5750 - 2s/epoch - 66ms/step
# Epoch 2/30
# 25/25 - 0s - loss: 0.6895 - accuracy: 0.5800 - val_loss: 0.6880 - val_accuracy: 0.5950 - 116ms/epoch - 5ms/step
# Epoch 3/30
# 25/25 - 0s - loss: 0.6849 - accuracy: 0.6050 - val_loss: 0.6837 - val_accuracy: 0.6300 - 125ms/epoch - 5ms/step
# Epoch 4/30
# 25/25 - 0s - loss: 0.6778 - accuracy: 0.6762 - val_loss: 0.6762 - val_accuracy: 0.6700 - 118ms/epoch - 5ms/step
# Epoch 5/30
# 25/25 - 0s - loss: 0.6663 - accuracy: 0.7025 - val_loss: 0.6663 - val_accuracy: 0.6950 - 119ms/epoch - 5ms/step
# Epoch 6/30
# 25/25 - 0s - loss: 0.6503 - accuracy: 0.7275 - val_loss: 0.6549 - val_accuracy: 0.6700 - 103ms/epoch - 4ms/step
# Epoch 7/30
# 25/25 - 0s - loss: 0.6287 - accuracy: 0.7725 - val_loss: 0.6340 - val_accuracy: 0.7000 - 112ms/epoch - 4ms/step
# Epoch 8/30
# 25/25 - 0s - loss: 0.6021 - accuracy: 0.7800 - val_loss: 0.6124 - val_accuracy: 0.7150 - 107ms/epoch - 4ms/step
# Epoch 9/30
# 25/25 - 0s - loss: 0.5728 - accuracy: 0.7975 - val_loss: 0.5910 - val_accuracy: 0.7550 - 129ms/epoch - 5ms/step
# Epoch 10/30
# 25/25 - 0s - loss: 0.5395 - accuracy: 0.8213 - val_loss: 0.5703 - val_accuracy: 0.7400 - 114ms/epoch - 5ms/step
# Epoch 11/30
# 25/25 - 0s - loss: 0.5065 - accuracy: 0.8425 - val_loss: 0.5524 - val_accuracy: 0.7450 - 109ms/epoch - 4ms/step
# Epoch 12/30
# 25/25 - 0s - loss: 0.4763 - accuracy: 0.8400 - val_loss: 0.5428 - val_accuracy: 0.7550 - 131ms/epoch - 5ms/step
# Epoch 13/30
# 25/25 - 0s - loss: 0.4490 - accuracy: 0.8450 - val_loss: 0.5193 - val_accuracy: 0.7500 - 138ms/epoch - 6ms/step
# Epoch 14/30
# 25/25 - 0s - loss: 0.4214 - accuracy: 0.8500 - val_loss: 0.4979 - val_accuracy: 0.7700 - 140ms/epoch - 6ms/step
# Epoch 15/30
# 25/25 - 0s - loss: 0.3995 - accuracy: 0.8562 - val_loss: 0.4910 - val_accuracy: 0.7750 - 140ms/epoch - 6ms/step
# Epoch 16/30
# 25/25 - 0s - loss: 0.3789 - accuracy: 0.8637 - val_loss: 0.4871 - val_accuracy: 0.7700 - 125ms/epoch - 5ms/step
# Epoch 17/30
# 25/25 - 0s - loss: 0.3627 - accuracy: 0.8700 - val_loss: 0.4764 - val_accuracy: 0.7500 - 115ms/epoch - 5ms/step
# Epoch 18/30
# 25/25 - 0s - loss: 0.3495 - accuracy: 0.8725 - val_loss: 0.4946 - val_accuracy: 0.7350 - 125ms/epoch - 5ms/step
# Epoch 19/30
# 25/25 - 0s - loss: 0.3375 - accuracy: 0.8775 - val_loss: 0.4785 - val_accuracy: 0.7700 - 116ms/epoch - 5ms/step
# Epoch 20/30
# 25/25 - 0s - loss: 0.3264 - accuracy: 0.8775 - val_loss: 0.4798 - val_accuracy: 0.7850 - 120ms/epoch - 5ms/step
# Epoch 21/30
# 25/25 - 0s - loss: 0.3195 - accuracy: 0.8813 - val_loss: 0.4903 - val_accuracy: 0.7550 - 135ms/epoch - 5ms/step
# Epoch 22/30
# 25/25 - 0s - loss: 0.3113 - accuracy: 0.8825 - val_loss: 0.4937 - val_accuracy: 0.7500 - 127ms/epoch - 5ms/step
# Epoch 23/30
# 25/25 - 0s - loss: 0.3021 - accuracy: 0.8863 - val_loss: 0.4796 - val_accuracy: 0.7750 - 117ms/epoch - 5ms/step
# Epoch 24/30
# 25/25 - 0s - loss: 0.2945 - accuracy: 0.8800 - val_loss: 0.4949 - val_accuracy: 0.7600 - 135ms/epoch - 5ms/step
# Epoch 25/30
# 25/25 - 0s - loss: 0.2902 - accuracy: 0.8888 - val_loss: 0.4910 - val_accuracy: 0.7700 - 125ms/epoch - 5ms/step
# Epoch 26/30
# 25/25 - 0s - loss: 0.2815 - accuracy: 0.8913 - val_loss: 0.4970 - val_accuracy: 0.7600 - 92ms/epoch - 4ms/step
# Epoch 27/30
# 25/25 - 0s - loss: 0.2771 - accuracy: 0.8925 - val_loss: 0.4985 - val_accuracy: 0.7700 - 92ms/epoch - 4ms/step
# Epoch 28/30
# 25/25 - 0s - loss: 0.2737 - accuracy: 0.8913 - val_loss: 0.4986 - val_accuracy: 0.7700 - 90ms/epoch - 4ms/step
# Epoch 29/30
# 25/25 - 0s - loss: 0.2680 - accuracy: 0.8963 - val_loss: 0.5145 - val_accuracy: 0.7550 - 93ms/epoch - 4ms/step
# Epoch 30/30
# 25/25 - 0s - loss: 0.2653 - accuracy: 0.8950 - val_loss: 0.5198 - val_accuracy: 0.7600 - 92ms/epoch - 4ms/step
